# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set()

# %%
# %matplotlib inline

# %%
df = pd.read_csv('fertility.csv')

# %%
df.head(3)
# Out:
#    season   age  childish_diseases  accident  surgical  high_fevers  \
# 0   -0.33  0.69                  0         1         1            0
# 1   -0.33  0.94                  1         0         1            0
# 2   -0.33  0.50                  1         0         0            0
#
#    frequency_alcohol  smoking_habit  hours_sitting diagnosis
# 0                0.8              0           0.88         N
# 1                0.8              1           0.31         O
# 2                1.0             -1           0.50         N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
# season               100 non-null float64
# age                  100 non-null float64
# childish_diseases    100 non-null int64
# accident             100 non-null int64
# surgical             100 non-null int64
# high_fevers          100 non-null int64
# frequency_alcohol    100 non-null float64
# smoking_habit        100 non-null int64
# hours_sitting        100 non-null float64
# diagnosis            100 non-null object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 7.9+ KB

# %%
df['diagnosis'] = df['diagnosis'].map( {'N' : 1, 'O': 0}).astype(int)

# %%
df['age'] = round((df['age'] / 0.0555555555555556) + 18)

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
sns.pairplot(df)
